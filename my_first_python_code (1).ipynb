# %%
print("hello World")
# Out:
# hello World

# %%
print("My nane is Dr Hongmei chi")
# Out:
# My nane is Dr Hongmei chi

# %%
sum = 10+5
difference = 10 -5
product = 10*5
division = 10/5
print(sum)
print(difference)
print(product)
print(division)
# Out:
# 15
# 5
# 50
# 2.0

# %%
# age_in_seconds.py

age_years = 57
age_seconds = age_years * 365 * 24 * 60 * 60

print(f"I am {age_years} years old", end = ", ")
print(f"which is {age_seconds:,} seconds.")
# Out:
# I am 57 years old, which is 1,797,552,000 seconds.
